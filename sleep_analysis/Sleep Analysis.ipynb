# %%
# Import dependencies 
import pandas as pd

# %%
# Read in the datset and select only the columns that are needed relating to sleep data
sleep_df = pd.read_csv('sleep_analysis.csv', usecols =['date','Sleep Score','Sleep Score','Total Sleep Score','Restfulness Score','Total Sleep Duration', 'Total Bedtime ', 'Awake Time','REM Sleep Duration', 'Light Sleep Duration', 'Deep Sleep Duration','Bedtime Start','Move Every Hour Score','Sleep Balance Score'])

# %%
# Convert duration times from seconds to hours
sleep_df['Total Sleep Duration'] = sleep_df['Total Sleep Duration'] / 60**2
sleep_df['Awake Time'] = sleep_df['Awake Time'] / 60**2
sleep_df['Total Bedtime '] = sleep_df['Total Bedtime '] / 60**2
sleep_df['REM Sleep Duration'] = sleep_df['REM Sleep Duration'] / 60**2
sleep_df['Light Sleep Duration'] = sleep_df['Light Sleep Duration'] / 60**2
sleep_df['Deep Sleep Duration'] = sleep_df['Deep Sleep Duration'] / 60**2

# %%
sleep_df.sort_values(by=['date'],ascending=False)
# Out:
#            date  Sleep Score  Total Sleep Score  Restfulness Score  \
# 128  2022-11-06         85.0               84.0               63.0
# 127  2022-11-05         76.0               72.0               64.0
# 126  2022-11-04         74.0               69.0               64.0
# 125  2022-11-03         84.0               85.0               64.0
# 124  2022-11-02         80.0               75.0               63.0
# ..          ...          ...                ...                ...
# 4    2022-06-26         86.0              100.0               69.0
# 3    2022-06-25         57.0               50.0               49.0
# 2    2022-06-24         69.0               58.0               66.0
# 1    2022-06-23         70.0               69.0               67.0
# 0    2022-06-22         77.0               77.0               70.0
#
#      Total Sleep Duration  Total Bedtime   Awake Time  REM Sleep Duration  \
# 128              7.891667        8.883333    0.991667            1.800000
# ...

# %%
sleep_df.columns
# Out:
# Index(['date', 'Sleep Score', 'Total Sleep Score', 'Restfulness Score',
#        'Total Sleep Duration', 'Total Bedtime ', 'Awake Time',
#        'REM Sleep Duration', 'Light Sleep Duration', 'Deep Sleep Duration',
#        'Bedtime Start', 'Move Every Hour Score', 'Sleep Balance Score'],
#       dtype='object')
